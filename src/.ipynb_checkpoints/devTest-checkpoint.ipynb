# %%
import S3Tools
import datetimeTools
import pandas as pd
import boto3

data = S3Tools.preview_csv_dataset(bucket='colinmec-nyc-tlc-5pc',key='trip data/yellow_tripdata_2009-01.csv',rows=1000000)
#data = S3Tools.preview_csv_dataset(bucket='noaa-csv-data',key='Central-Park/725053-94728-2012-06.csv',rows=5000)
#data = S3Tools.preview_csv_dataset(bucket='noaa-csv-data',key='JFK-Intl/744860-94789-2015-01.csv',rows=5000)
#data.loc[250:300]
data.shape[0]

#s3 = boto3.client('s3')
#s3.download_file('nyc-tlc', 'trip data/green_tripdata_2017-12.csv', 'green_tripdata_2017-12.csv')
# Out:
#    vendor_name Trip_Pickup_DateTime Trip_Dropoff_DateTime  Passenger_Count  \
# 0          CMT  2009-01-27 15:00:03   2009-01-27 15:12:26                1
# 1          VTS  2009-01-24 16:26:00   2009-01-24 16:36:00                1
# 2          CMT  2009-01-14 23:22:00   2009-01-14 23:31:05                1
# 3          VTS  2009-01-17 00:49:00   2009-01-17 00:52:00                1
# 4          CMT  2009-01-27 02:27:42   2009-01-27 02:40:25                1
# 5          DDS  2009-01-31 12:16:51   2009-01-31 12:23:01                3
# 6          VTS  2009-01-17 17:09:00   2009-01-17 17:19:00                1
# 7          VTS  2009-01-23 09:44:00   2009-01-23 09:54:00                2
# 8          CMT  2009-01-15 20:00:09   2009-01-15 20:03:33                1
# 9          CMT  2009-01-23 01:19:59   2009-01-23 01:23:08                1
# 10         VTS  2009-01-13 11:37:00   2009-01-13 11:47:00                1
# ...

# %%
data.to_csv(r'yellow_tripdata_2010-01.csv',index=False)

# %%
S3Tools.uploadFileFromLocal('yellow_tripdata_2010-01.csv', 'colinmec-test', 'trip data/yellow_tripdata_2010-01.csv')

# %%
import datetimeTools as dtt
from datetime import datetime
datetime.fromtimestamp(1420923600)
# Out:
# datetime.datetime(2015, 1, 10, 21, 0)

# %%
test = [a + 10 for a in range(12)]
indices = [idx for idx, val in enumerate(test) if val <= 9]
test[None]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-f9c977a2f211> in <module>()
#       1 test = [a + 10 for a in range(12)]
#       2 indices = [idx for idx, val in enumerate(test) if val <= 9]
# ----> 3 test[None]
#
# TypeError: list indices must be integers, not NoneType

# %%
sourceBucket = 'nyc-tlc'
partialPath  = 'trip data/yellow_tripdata_'

years  = [val + 2009 for val in range(11)]
months = [val + 1 for val in range(12)]

keys = []
for yr in years:
    for mn in months:
        keys.append(partialPath + str(yr) + '-' + str(mn).zfill(2) + '.csv')
keys
# Out:
# ['trip data/yellow_tripdata_2009-01.csv',
#  'trip data/yellow_tripdata_2009-02.csv',
#  'trip data/yellow_tripdata_2009-03.csv',
#  'trip data/yellow_tripdata_2009-04.csv',
#  'trip data/yellow_tripdata_2009-05.csv',
#  'trip data/yellow_tripdata_2009-06.csv',
#  'trip data/yellow_tripdata_2009-07.csv',
#  'trip data/yellow_tripdata_2009-08.csv',
#  'trip data/yellow_tripdata_2009-09.csv',
#  'trip data/yellow_tripdata_2009-10.csv',
#  'trip data/yellow_tripdata_2009-11.csv',
#  'trip data/yellow_tripdata_2009-12.csv',
#  'trip data/yellow_tripdata_2010-01.csv',
#  'trip data/yellow_tripdata_2010-02.csv',
#  'trip data/yellow_tripdata_2010-03.csv',
#  'trip data/yellow_tripdata_2010-04.csv',
#  'trip data/yellow_tripdata_2010-05.csv',
#  'trip data/yellow_tripdata_2010-06.csv',
#  'trip data/yellow_tripdata_2010-07.csv',
#  'trip data/yellow_tripdata_2010-08.csv',
#  'trip data/yellow_tripdata_2010-09.csv',
#  'trip data/yellow_tripdata_2010-10.csv',
# ...

# %%
import datetimeTools
ts = datetimeTools.strArrayToTimeStamps(data["tpep_pickup_datetime"].values)
data.insert(2, "pUTimeStamp", ts, True)
data.head(20)
# Out:
#     VendorID tpep_pickup_datetime  pUTimeStamp tpep_dropoff_datetime  \
# 0          1  2019-06-01 00:55:13   1559350513   2019-06-01 00:56:17
# 1          1  2019-06-01 00:06:31   1559347591   2019-06-01 00:06:52
# 2          1  2019-06-01 00:17:05   1559348225   2019-06-01 00:36:38
# 3          1  2019-06-01 00:59:02   1559350742   2019-06-01 00:59:12
# 4          1  2019-06-01 00:03:25   1559347405   2019-06-01 00:15:42
# 5          1  2019-06-01 00:28:31   1559348911   2019-06-01 00:39:23
# 6          1  2019-06-01 00:46:46   1559350006   2019-06-01 00:50:55
# 7          1  2019-06-01 00:54:49   1559350489   2019-06-01 01:02:57
# 8          1  2019-06-01 00:09:57   1559347797   2019-06-01 00:25:54
# 9          1  2019-06-01 00:29:12   1559348952   2019-06-01 01:03:13
# 10         2  2019-06-01 00:01:48   1559347308   2019-06-01 00:16:06
# 11         2  2019-06-01 00:17:41   1559348261   2019-06-01 00:30:22
# 12         2  2019-06-01 00:33:26   1559349206   2019-06-01 00:39:18
# ...

# %%
datetime.fromtimestamp(timeStmp)
datetime.strftime(timeType,'%Y-%m-%d %H:%M:%S')

# %%
import sys
del sys.modules['datetimeTools']

# %%
import GlobalVar
schema = ', '.join([var1 + ' ' + var2 for var1, var2 in \
          zip(GlobalVar.getVal('weatherFields'), GlobalVar.getVal('weatherDataType'))])

# %%
schema
# Out:
# 'timeStamp int, airTemp float, dewPt float, pressure float, windDir int, windSpd float, cloudCover string, precip1Hr float, precip6Hr float'

# %%
from datetime import datetime
datetime.fromtimestamp(1549065600)
# Out:
# datetime.datetime(2019, 2, 2, 0, 0)

# %%
A = ['a1','a2','a3']
B = ['b1','b2','b3']
C = ['c1','c2','c3']
D = [A, B, C]
D[0]
# Out:
# ['a1', 'a2', 'a3']

# %%
allStations = [True, True, True, False]
(1 == 1) and not False in allStations
# Out:
# False

# %%
someFunc = lambda x, y: x + y + 1

# %%
someFunc(2,4)
# Out:
# 7
